# %% [markdown]
# # Motivations

# %% [markdown]
# When n is large, logisitic regression just doesn't cut it, so we have to use neural networks.
#
# Neural networks were motivated by how the brain works.

# %% [markdown]
# # Neural Networks

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
